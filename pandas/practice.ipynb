# %%
import numpy as np
import pandas as pd

# %%
name=["jawad",'ijaz','atif','abdullah','khan']

pd.Series(name,name='student name')
# Out:
# 0       jawad
# 1        ijaz
# 2        atif
# 3    abdullah
# 4        khan
# Name: student name, dtype: str

# %%
rollno=[12,34,65,76,97]

pd.Series(rollno)
# Out:
# 0    12
# 1    34
# 2    65
# 3    76
# 4    97
# dtype: int64

# %%
marks=[99,78,87,56,87]
subjects=['English','math','pakstudy','physics','bio']

pd.Series(marks,index=subjects)
# Out:
# English     99
# math        78
# pakstudy    87
# physics     56
# bio         87
# dtype: int64

# %%
marks={
    'English':87,
    'math':68,
    'pakstudy':89,
    'physics':67,
    'bio':68,

}
dict_markspd=pd.Series(marks)
dict_markspd
# Out:
# English     87
# math        68
# pakstudy    89
# physics     67
# bio         68
# dtype: int64

# %%
dict_markspd.dtype
# Out:
# dtype('int64')

# %%
dict_markspd.size
# Out:
# 5

# %%
dict_markspd.index
# Out:
# Index(['English', 'math', 'pakstudy', 'physics', 'bio'], dtype='str')

# %%
subscribe=pd.read_csv('subs.csv').squeeze()
subscribe
# Out:
# 0       48
# 1       57
# 2       40
# 3       43
# 4       44
#       ...
# 360    231
# 361    226
# 362    155
# 363    144
# 364    172
# Name: Subscribers gained, Length: 365, dtype: int64
